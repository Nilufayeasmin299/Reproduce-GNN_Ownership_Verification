# %% [markdown]
# <a href="https://colab.research.google.com/github/Nilufayeasmin299/Reproduce-GNN_Ownership_Verification/blob/main/Final_Preproduction_of_GNN_Ownership_verification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torch-geometric numpy scikit-learn matplotlib tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.10/dist-packages (2.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.11.9)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2024.8.30)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid, Amazon
from torch_geometric.nn import GCNConv, GATConv, SAGEConv, GINConv
from torch_geometric.transforms import NormalizeFeatures
from sklearn.metrics import accuracy_score, confusion_matrix
import random
import numpy as np

# %%
# Configuration
CONFIG = {
    'learning_rate': 0.005,
    'weight_decay': 5e-4,
    'hidden_dim': 256,  # Increased hidden dimension for deeper representations
    'dropout': 0.3,
    'epochs': 400,
    'edge_dropout_rate': 0.1,
    'mask_ratios': [0.0, 0.05, 0.1, 0.2],
    'architectures': ['GCN', 'GAT', 'SAGE', 'GIN'],
    'settings': ['transductive', 'inductive'],
    'early_stopping_patience': 30  # Early stopping patience
}

# %%
# Set seeds for reproducibility
random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

# %%
def create_masks(data, train_ratio=0.6, val_ratio=0.2):
    num_nodes = data.num_nodes
    indices = torch.randperm(num_nodes)
    train_size = int(train_ratio * num_nodes)
    val_size = int(val_ratio * num_nodes)

    data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
    data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
    data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)

    data.train_mask[indices[:train_size]] = True
    data.val_mask[indices[train_size:train_size + val_size]] = True
    data.test_mask[indices[train_size + val_size:]] = True
    return data

def augment_data(data, edge_dropout_rate):
    num_edges = data.edge_index.shape[1]
    keep_edges = int(num_edges * (1 - edge_dropout_rate))
    perm = torch.randperm(num_edges)[:keep_edges]
    data.edge_index = data.edge_index[:, perm]
    return data

def mask_features(data, mask_ratio):
    num_features = data.x.shape[1]
    num_masked = int(mask_ratio * num_features)
    mask_indices = torch.randperm(num_features)[:num_masked]
    data.x[:, mask_indices] = 0
    return data

def split_inductive(data):
    """Simulate inductive setting by splitting the graph into disjoint subgraphs."""
    num_nodes = data.num_nodes
    indices = torch.randperm(num_nodes)
    split_idx = num_nodes // 2
    train_idx = indices[:split_idx]
    test_idx = indices[split_idx:]

    train_mask = torch.zeros(num_nodes, dtype=torch.bool)
    test_mask = torch.zeros(num_nodes, dtype=torch.bool)

    train_mask[train_idx] = True
    test_mask[test_idx] = True

    data.train_mask = train_mask
    data.test_mask = test_mask
    return data

# %%
class EnhancedGNN(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers=3, dropout=0.3, arch='GCN'):
        super().__init__()
        self.num_layers = num_layers
        self.dropout = dropout
        self.arch = arch

        self.convs = nn.ModuleList()
        self.batch_norms = nn.ModuleList()

        if arch == 'GCN':
            self.convs.append(GCNConv(in_channels, hidden_channels))
        elif arch == 'GAT':
            self.convs.append(GATConv(in_channels, hidden_channels))
        elif arch == 'SAGE':
            self.convs.append(SAGEConv(in_channels, hidden_channels))
        elif arch == 'GIN':
            gin_nn = nn.Sequential(
                nn.Linear(in_channels, hidden_channels),
                nn.ReLU(),
                nn.Linear(hidden_channels, hidden_channels)
            )
            self.convs.append(GINConv(gin_nn))

        self.batch_norms.append(nn.BatchNorm1d(hidden_channels))

        for _ in range(num_layers - 2):
            if arch == 'GCN':
                self.convs.append(GCNConv(hidden_channels, hidden_channels))
            elif arch == 'GAT':
                self.convs.append(GATConv(hidden_channels, hidden_channels))
            elif arch == 'SAGE':
                self.convs.append(SAGEConv(hidden_channels, hidden_channels))
            elif arch == 'GIN':
                gin_nn = nn.Sequential(
                    nn.Linear(hidden_channels, hidden_channels),
                    nn.ReLU(),
                    nn.Linear(hidden_channels, hidden_channels)
                )
                self.convs.append(GINConv(gin_nn))
            self.batch_norms.append(nn.BatchNorm1d(hidden_channels))

        if arch == 'GCN':
            self.convs.append(GCNConv(hidden_channels, out_channels))
        elif arch == 'GAT':
            self.convs.append(GATConv(hidden_channels, out_channels))
        elif arch == 'SAGE':
            self.convs.append(SAGEConv(hidden_channels, out_channels))
        elif arch == 'GIN':
            gin_nn = nn.Sequential(
                nn.Linear(hidden_channels, hidden_channels),
                nn.ReLU(),
                nn.Linear(hidden_channels, out_channels)
            )
            self.convs.append(GINConv(gin_nn))

    def forward(self, x, edge_index):
        for i in range(self.num_layers - 1):
            x = self.convs[i](x, edge_index)
            x = self.batch_norms[i](x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)

        x = self.convs[-1](x, edge_index)
        return x

def train_and_evaluate(model, data, config):
    optimizer = torch.optim.Adam(model.parameters(), lr=config['learning_rate'], weight_decay=config['weight_decay'])
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)
    criterion = nn.CrossEntropyLoss()

    best_loss = float('inf')
    patience_counter = 0

    for epoch in range(config['epochs']):
        model.train()
        optimizer.zero_grad()
        out = model(data.x, data.edge_index)
        loss = criterion(out[data.train_mask], data.y[data.train_mask])
        loss.backward()
        optimizer.step()

        scheduler.step(loss)

        model.eval()
        pred = out.argmax(dim=1)
        acc = accuracy_score(data.y[data.test_mask].cpu(), pred[data.test_mask].cpu())

        cm = confusion_matrix(data.y[data.test_mask].cpu(), pred[data.test_mask].cpu())
        print(f"Confusion matrix shape: {cm.shape}")
        #Calculate FPR and FNR for multi-class classification
        FP = cm.sum(axis=0) - np.diag(cm)
        FN = cm.sum(axis=1) - np.diag(cm)
        TP = np.diag(cm)
        TN = cm.sum() - (FP + FN + TP)

        # Then calculate the rates using these arrays:
        FPR = FP / (FP + TN)
        FNR = FN / (TP + FN)

        # To get the average rates across all classes:
        avg_fpr = np.mean(FPR)
        avg_fnr = np.mean(FNR)

        print(f"Epoch {epoch} | Loss: {loss:.4f} | Accuracy: {acc:.4f} | FPR: {avg_fpr:.4f} | FNR: {avg_fnr:.4f}")

        # Early stopping based on validation loss
        if loss < best_loss:
            best_loss = loss
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= config['early_stopping_patience']:
            print("Early stopping triggered.")
            break

    return acc, avg_fpr, avg_fnr # Return the average rates

# %%
# Example usage with different datasets, settings, and masking ratios:
datasets = [
    ('Cora', Planetoid(root='/tmp/Cora', name='Cora', transform=NormalizeFeatures())),
    ('CiteSeer', Planetoid(root='/tmp/CiteSeer', name='CiteSeer', transform=NormalizeFeatures())),
    ('PubMed', Planetoid(root='/tmp/PubMed', name='PubMed', transform=NormalizeFeatures())),
    ('Amazon', Amazon(root='/tmp/Amazon', name='Computers'))
]

results = {}

# %%
for dataset_name, dataset in datasets:
    print(f"Running experiments on dataset: {dataset_name}")
    data = dataset[0]
    # Move the initial data to the appropriate device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    data = data.to(device)
    dataset_results = []

    for setting in CONFIG['settings']:
        print(f"\nRunning in {setting} setting")
        if setting == 'inductive':
            current_data = split_inductive(data.clone())  # Use current_data
        else:
            current_data = create_masks(data.clone())  # Use current_data

        for mask_ratio in CONFIG['mask_ratios']:
            print(f"\nRunning experiment with mask ratio: {mask_ratio}")
            masked_data = mask_features(current_data.clone(), mask_ratio)  # Clone from current_data

            for arch in CONFIG['architectures']:
                print(f"\nTesting architecture: {arch}")
                model = EnhancedGNN(
                    in_channels=data.num_features,  # Access from original data
                    hidden_channels=CONFIG['hidden_dim'],
                    out_channels=dataset.num_classes,  # Access from original dataset
                    dropout=CONFIG['dropout'],
                    arch=arch
                ).to(device) # Ensure the model is on the correct device
                masked_data = augment_data(masked_data, CONFIG['edge_dropout_rate'])
                # Move masked_data to the same device as the model
                masked_data = masked_data.to(device)
                acc, fpr, fnr = train_and_evaluate(model, masked_data, CONFIG)

                dataset_results.append({
                    'setting': setting,
                    'mask_ratio': mask_ratio,
                    'architecture': arch,
                    'accuracy': round(acc, 4),
                    'false_positive_rate': round(fpr, 4),
                    'false_negative_rate': round(fnr, 4)
                })

    results[dataset_name] = dataset_results
# Out:
# Streaming output truncated to the last 5000 lines.
# Confusion matrix shape: (10, 10)
# Epoch 231 | Loss: 0.0574 | Accuracy: 0.8921 | FPR: 0.0138 | FNR: 0.1273
# Confusion matrix shape: (10, 10)
# Epoch 232 | Loss: 0.0517 | Accuracy: 0.8938 | FPR: 0.0135 | FNR: 0.1144
# Confusion matrix shape: (10, 10)
# Epoch 233 | Loss: 0.0511 | Accuracy: 0.8953 | FPR: 0.0132 | FNR: 0.1127
# Confusion matrix shape: (10, 10)
# Epoch 234 | Loss: 0.0574 | Accuracy: 0.8967 | FPR: 0.0131 | FNR: 0.1049
# Confusion matrix shape: (10, 10)
# Epoch 235 | Loss: 0.0519 | Accuracy: 0.8915 | FPR: 0.0137 | FNR: 0.1126
# Confusion matrix shape: (10, 10)
# Epoch 236 | Loss: 0.0517 | Accuracy: 0.8899 | FPR: 0.0140 | FNR: 0.1156
# Confusion matrix shape: (10, 10)
# Epoch 237 | Loss: 0.0500 | Accuracy: 0.8941 | FPR: 0.0134 | FNR: 0.1154
# Confusion matrix shape: (10, 10)
# Epoch 238 | Loss: 0.0530 | Accuracy: 0.8937 | FPR: 0.0135 | FNR: 0.1122
# Confusion matrix shape: (10, 10)
# Epoch 239 | Loss: 0.0510 | Accuracy: 0.8978 | FPR: 0.0129 | FNR: 0.1048
# Confusion matrix shape: (10, 10)
# Epoch 240 | Loss: 0.0521 | Accuracy: 0.8931 | FPR: 0.0134 | FNR: 0.1147
# Confusion matrix shape: (10, 10)
# Epoch 241 | Loss: 0.0495 | Accuracy: 0.8941 | FPR: 0.0134 | FNR: 0.1132
# Confusion matrix shape: (10, 10)
# Epoch 242 | Loss: 0.0494 | Accuracy: 0.8931 | FPR: 0.0135 | FNR: 0.1132
# Confusion matrix shape: (10, 10)
# Epoch 243 | Loss: 0.0516 | Accuracy: 0.8896 | FPR: 0.0141 | FNR: 0.1229
# Confusion matrix shape: (10, 10)
# Epoch 244 | Loss: 0.0481 | Accuracy: 0.8922 | FPR: 0.0138 | FNR: 0.1195
# Confusion matrix shape: (10, 10)
# Epoch 245 | Loss: 0.0520 | Accuracy: 0.8947 | FPR: 0.0134 | FNR: 0.1119
# Confusion matrix shape: (10, 10)
# Epoch 246 | Loss: 0.0490 | Accuracy: 0.8978 | FPR: 0.0130 | FNR: 0.1058
# Confusion matrix shape: (10, 10)
# Epoch 247 | Loss: 0.0493 | Accuracy: 0.8940 | FPR: 0.0135 | FNR: 0.1096
# Confusion matrix shape: (10, 10)
# Epoch 248 | Loss: 0.0515 | Accuracy: 0.8960 | FPR: 0.0132 | FNR: 0.1162
# Confusion matrix shape: (10, 10)
# Epoch 249 | Loss: 0.0527 | Accuracy: 0.8873 | FPR: 0.0145 | FNR: 0.1344
# Confusion matrix shape: (10, 10)
# Epoch 250 | Loss: 0.0510 | Accuracy: 0.8933 | FPR: 0.0136 | FNR: 0.1132
# Confusion matrix shape: (10, 10)
# Epoch 251 | Loss: 0.0502 | Accuracy: 0.8924 | FPR: 0.0136 | FNR: 0.1144
# Confusion matrix shape: (10, 10)
# Epoch 252 | Loss: 0.0490 | Accuracy: 0.8914 | FPR: 0.0136 | FNR: 0.1146
# Confusion matrix shape: (10, 10)
# Epoch 253 | Loss: 0.0492 | Accuracy: 0.8917 | FPR: 0.0137 | FNR: 0.1178
# Confusion matrix shape: (10, 10)
# Epoch 254 | Loss: 0.0541 | Accuracy: 0.8873 | FPR: 0.0143 | FNR: 0.1148
# Confusion matrix shape: (10, 10)
# Epoch 255 | Loss: 0.0477 | Accuracy: 0.8869 | FPR: 0.0143 | FNR: 0.1261
# Confusion matrix shape: (10, 10)
# Epoch 256 | Loss: 0.0495 | Accuracy: 0.8930 | FPR: 0.0136 | FNR: 0.1279
# Confusion matrix shape: (10, 10)
# Epoch 257 | Loss: 0.0460 | Accuracy: 0.8924 | FPR: 0.0136 | FNR: 0.1193
# Confusion matrix shape: (10, 10)
# Epoch 258 | Loss: 0.0547 | Accuracy: 0.8908 | FPR: 0.0138 | FNR: 0.1117
# Confusion matrix shape: (10, 10)
# Epoch 259 | Loss: 0.0490 | Accuracy: 0.8919 | FPR: 0.0137 | FNR: 0.1156
# Confusion matrix shape: (10, 10)
# Epoch 260 | Loss: 0.0456 | Accuracy: 0.8912 | FPR: 0.0138 | FNR: 0.1131
# Confusion matrix shape: (10, 10)
# Epoch 261 | Loss: 0.0487 | Accuracy: 0.8925 | FPR: 0.0137 | FNR: 0.1162
# Confusion matrix shape: (10, 10)
# Epoch 262 | Loss: 0.0455 | Accuracy: 0.8922 | FPR: 0.0137 | FNR: 0.1150
# Confusion matrix shape: (10, 10)
# Epoch 263 | Loss: 0.0449 | Accuracy: 0.8937 | FPR: 0.0136 | FNR: 0.1096
# Confusion matrix shape: (10, 10)
# Epoch 264 | Loss: 0.0476 | Accuracy: 0.8937 | FPR: 0.0134 | FNR: 0.1084
# Confusion matrix shape: (10, 10)
# Epoch 265 | Loss: 0.0486 | Accuracy: 0.8925 | FPR: 0.0136 | FNR: 0.1197
# Confusion matrix shape: (10, 10)
# Epoch 266 | Loss: 0.0449 | Accuracy: 0.8914 | FPR: 0.0137 | FNR: 0.1185
# Confusion matrix shape: (10, 10)
# Epoch 267 | Loss: 0.0463 | Accuracy: 0.8912 | FPR: 0.0139 | FNR: 0.1146
# Confusion matrix shape: (10, 10)
# Epoch 268 | Loss: 0.0496 | Accuracy: 0.8915 | FPR: 0.0136 | FNR: 0.1152
# Confusion matrix shape: (10, 10)
# Epoch 269 | Loss: 0.0476 | Accuracy: 0.8886 | FPR: 0.0142 | FNR: 0.1205
# Confusion matrix shape: (10, 10)
# Epoch 270 | Loss: 0.0471 | Accuracy: 0.8901 | FPR: 0.0142 | FNR: 0.1243
# Confusion matrix shape: (10, 10)
# Epoch 271 | Loss: 0.0499 | Accuracy: 0.8921 | FPR: 0.0140 | FNR: 0.1218
# Confusion matrix shape: (10, 10)
# Epoch 272 | Loss: 0.0495 | Accuracy: 0.8925 | FPR: 0.0136 | FNR: 0.1092
# Confusion matrix shape: (10, 10)
# Epoch 273 | Loss: 0.0465 | Accuracy: 0.8933 | FPR: 0.0134 | FNR: 0.1127
# Confusion matrix shape: (10, 10)
# Epoch 274 | Loss: 0.0494 | Accuracy: 0.8893 | FPR: 0.0140 | FNR: 0.1184
# Confusion matrix shape: (10, 10)
# Epoch 275 | Loss: 0.0419 | Accuracy: 0.8871 | FPR: 0.0143 | FNR: 0.1249
# Confusion matrix shape: (10, 10)
# Epoch 276 | Loss: 0.0479 | Accuracy: 0.8921 | FPR: 0.0139 | FNR: 0.1212
# Confusion matrix shape: (10, 10)
# Epoch 277 | Loss: 0.0462 | Accuracy: 0.8890 | FPR: 0.0143 | FNR: 0.1160
# Confusion matrix shape: (10, 10)
# Epoch 278 | Loss: 0.0456 | Accuracy: 0.8911 | FPR: 0.0138 | FNR: 0.1143
# Confusion matrix shape: (10, 10)
# Epoch 279 | Loss: 0.0410 | Accuracy: 0.8885 | FPR: 0.0143 | FNR: 0.1218
# Confusion matrix shape: (10, 10)
# Epoch 280 | Loss: 0.0459 | Accuracy: 0.8931 | FPR: 0.0136 | FNR: 0.1172
# Confusion matrix shape: (10, 10)
# Epoch 281 | Loss: 0.0410 | Accuracy: 0.8953 | FPR: 0.0132 | FNR: 0.1152
# Confusion matrix shape: (10, 10)
# Epoch 282 | Loss: 0.0429 | Accuracy: 0.8934 | FPR: 0.0135 | FNR: 0.1139
# Confusion matrix shape: (10, 10)
# Epoch 283 | Loss: 0.0389 | Accuracy: 0.8893 | FPR: 0.0141 | FNR: 0.1210
# Confusion matrix shape: (10, 10)
# Epoch 284 | Loss: 0.0390 | Accuracy: 0.8898 | FPR: 0.0141 | FNR: 0.1198
# Confusion matrix shape: (10, 10)
# Epoch 285 | Loss: 0.0458 | Accuracy: 0.8937 | FPR: 0.0136 | FNR: 0.1176
# Confusion matrix shape: (10, 10)
# Epoch 286 | Loss: 0.0401 | Accuracy: 0.8922 | FPR: 0.0138 | FNR: 0.1210
# Confusion matrix shape: (10, 10)
# Epoch 287 | Loss: 0.0372 | Accuracy: 0.8949 | FPR: 0.0133 | FNR: 0.1121
# Confusion matrix shape: (10, 10)
# Epoch 288 | Loss: 0.0409 | Accuracy: 0.8912 | FPR: 0.0138 | FNR: 0.1130
# Confusion matrix shape: (10, 10)
# Epoch 289 | Loss: 0.0415 | Accuracy: 0.8914 | FPR: 0.0138 | FNR: 0.1165
# Confusion matrix shape: (10, 10)
# Epoch 290 | Loss: 0.0383 | Accuracy: 0.8953 | FPR: 0.0132 | FNR: 0.1127
# Confusion matrix shape: (10, 10)
# Epoch 291 | Loss: 0.0360 | Accuracy: 0.8941 | FPR: 0.0136 | FNR: 0.1165
# Confusion matrix shape: (10, 10)
# Epoch 292 | Loss: 0.0386 | Accuracy: 0.8882 | FPR: 0.0143 | FNR: 0.1223
# Confusion matrix shape: (10, 10)
# Epoch 293 | Loss: 0.0384 | Accuracy: 0.8908 | FPR: 0.0139 | FNR: 0.1160
# Confusion matrix shape: (10, 10)
# Epoch 294 | Loss: 0.0376 | Accuracy: 0.8944 | FPR: 0.0135 | FNR: 0.1094
# Confusion matrix shape: (10, 10)
# Epoch 295 | Loss: 0.0382 | Accuracy: 0.8934 | FPR: 0.0135 | FNR: 0.1127
# Confusion matrix shape: (10, 10)
# Epoch 296 | Loss: 0.0422 | Accuracy: 0.8908 | FPR: 0.0140 | FNR: 0.1211
# Confusion matrix shape: (10, 10)
# Epoch 297 | Loss: 0.0396 | Accuracy: 0.8970 | FPR: 0.0131 | FNR: 0.1163
# Confusion matrix shape: (10, 10)
# Epoch 298 | Loss: 0.0357 | Accuracy: 0.8941 | FPR: 0.0133 | FNR: 0.1113
# Confusion matrix shape: (10, 10)
# Epoch 299 | Loss: 0.0383 | Accuracy: 0.8940 | FPR: 0.0134 | FNR: 0.1090
# Confusion matrix shape: (10, 10)
# Epoch 300 | Loss: 0.0363 | Accuracy: 0.8877 | FPR: 0.0144 | FNR: 0.1249
# Confusion matrix shape: (10, 10)
# Epoch 301 | Loss: 0.0362 | Accuracy: 0.8893 | FPR: 0.0141 | FNR: 0.1231
# Confusion matrix shape: (10, 10)
# Epoch 302 | Loss: 0.0357 | Accuracy: 0.8938 | FPR: 0.0136 | FNR: 0.1158
# Epoch 345 | Loss: 0.0308 | Accuracy: 0.8855 | FPR: 0.0145 | FNR: 0.1236
# Confusion matrix shape: (10, 10)
# Epoch 346 | Loss: 0.0277 | Accuracy: 0.8864 | FPR: 0.0144 | FNR: 0.1184
# Confusion matrix shape: (10, 10)
# Epoch 347 | Loss: 0.0297 | Accuracy: 0.8886 | FPR: 0.0141 | FNR: 0.1224
# Confusion matrix shape: (10, 10)
# Epoch 348 | Loss: 0.0297 | Accuracy: 0.8909 | FPR: 0.0138 | FNR: 0.1151
# Confusion matrix shape: (10, 10)
# Epoch 349 | Loss: 0.0273 | Accuracy: 0.8874 | FPR: 0.0142 | FNR: 0.1213
# Confusion matrix shape: (10, 10)
# Epoch 350 | Loss: 0.0265 | Accuracy: 0.8876 | FPR: 0.0142 | FNR: 0.1199
# Confusion matrix shape: (10, 10)
# Epoch 351 | Loss: 0.0286 | Accuracy: 0.8869 | FPR: 0.0144 | FNR: 0.1264
# Confusion matrix shape: (10, 10)
# Epoch 352 | Loss: 0.0263 | Accuracy: 0.8853 | FPR: 0.0147 | FNR: 0.1257
# Confusion matrix shape: (10, 10)
# Epoch 353 | Loss: 0.0266 | Accuracy: 0.8861 | FPR: 0.0146 | FNR: 0.1252
# Confusion matrix shape: (10, 10)
# Epoch 354 | Loss: 0.0270 | Accuracy: 0.8889 | FPR: 0.0142 | FNR: 0.1233
# Confusion matrix shape: (10, 10)
# Epoch 355 | Loss: 0.0275 | Accuracy: 0.8908 | FPR: 0.0140 | FNR: 0.1188
# Confusion matrix shape: (10, 10)
# Epoch 356 | Loss: 0.0265 | Accuracy: 0.8905 | FPR: 0.0139 | FNR: 0.1177
# Confusion matrix shape: (10, 10)
# Epoch 357 | Loss: 0.0248 | Accuracy: 0.8883 | FPR: 0.0142 | FNR: 0.1186
# Confusion matrix shape: (10, 10)
# Epoch 358 | Loss: 0.0247 | Accuracy: 0.8887 | FPR: 0.0140 | FNR: 0.1177
# Confusion matrix shape: (10, 10)
# Epoch 359 | Loss: 0.0257 | Accuracy: 0.8886 | FPR: 0.0141 | FNR: 0.1185
# Confusion matrix shape: (10, 10)
# Epoch 360 | Loss: 0.0265 | Accuracy: 0.8889 | FPR: 0.0141 | FNR: 0.1155
# Confusion matrix shape: (10, 10)
# Epoch 361 | Loss: 0.0268 | Accuracy: 0.8873 | FPR: 0.0144 | FNR: 0.1269
# Confusion matrix shape: (10, 10)
# Epoch 362 | Loss: 0.0248 | Accuracy: 0.8867 | FPR: 0.0144 | FNR: 0.1263
# Confusion matrix shape: (10, 10)
# Epoch 363 | Loss: 0.0256 | Accuracy: 0.8861 | FPR: 0.0145 | FNR: 0.1244
# Confusion matrix shape: (10, 10)
# Epoch 364 | Loss: 0.0236 | Accuracy: 0.8874 | FPR: 0.0143 | FNR: 0.1195
# Confusion matrix shape: (10, 10)
# Epoch 365 | Loss: 0.0264 | Accuracy: 0.8871 | FPR: 0.0143 | FNR: 0.1189
# Confusion matrix shape: (10, 10)
# Epoch 366 | Loss: 0.0260 | Accuracy: 0.8870 | FPR: 0.0143 | FNR: 0.1226
# Confusion matrix shape: (10, 10)
# Epoch 388 | Loss: 0.0231 | Accuracy: 0.8887 | FPR: 0.0142 | FNR: 0.1225
# Confusion matrix shape: (10, 10)
# Epoch 389 | Loss: 0.0224 | Accuracy: 0.8867 | FPR: 0.0145 | FNR: 0.1267
# Confusion matrix shape: (10, 10)
# Epoch 390 | Loss: 0.0233 | Accuracy: 0.8858 | FPR: 0.0144 | FNR: 0.1261
# Confusion matrix shape: (10, 10)
# Epoch 391 | Loss: 0.0222 | Accuracy: 0.8887 | FPR: 0.0142 | FNR: 0.1233
# Confusion matrix shape: (10, 10)
# Epoch 392 | Loss: 0.0238 | Accuracy: 0.8893 | FPR: 0.0140 | FNR: 0.1173
# Confusion matrix shape: (10, 10)
# Epoch 393 | Loss: 0.0245 | Accuracy: 0.8880 | FPR: 0.0142 | FNR: 0.1175
# Confusion matrix shape: (10, 10)
# Epoch 394 | Loss: 0.0238 | Accuracy: 0.8883 | FPR: 0.0142 | FNR: 0.1202
# Confusion matrix shape: (10, 10)
# Epoch 395 | Loss: 0.0229 | Accuracy: 0.8854 | FPR: 0.0145 | FNR: 0.1211
# Confusion matrix shape: (10, 10)
# Epoch 396 | Loss: 0.0245 | Accuracy: 0.8885 | FPR: 0.0141 | FNR: 0.1196
# Confusion matrix shape: (10, 10)
# Epoch 397 | Loss: 0.0251 | Accuracy: 0.8889 | FPR: 0.0140 | FNR: 0.1197
# Confusion matrix shape: (10, 10)
# Epoch 398 | Loss: 0.0218 | Accuracy: 0.8854 | FPR: 0.0146 | FNR: 0.1298
# Confusion matrix shape: (10, 10)
# Epoch 399 | Loss: 0.0216 | Accuracy: 0.8880 | FPR: 0.0143 | FNR: 0.1255
#
# Testing architecture: SAGE
# Confusion matrix shape: (10, 10)
# Epoch 0 | Loss: 2.3893 | Accuracy: 0.1194 | FPR: 0.1010 | FNR: 0.9046
# Confusion matrix shape: (10, 10)
# Epoch 1 | Loss: 1.4732 | Accuracy: 0.5390 | FPR: 0.0639 | FNR: 0.7585
# Confusion matrix shape: (10, 10)
# Epoch 2 | Loss: 1.2693 | Accuracy: 0.5653 | FPR: 0.0550 | FNR: 0.7203
# Confusion matrix shape: (10, 10)
# Epoch 3 | Loss: 0.9713 | Accuracy: 0.6883 | FPR: 0.0400 | FNR: 0.5659
# Confusion matrix shape: (10, 10)
# Epoch 4 | Loss: 0.8512 | Accuracy: 0.7145 | FPR: 0.0374 | FNR: 0.5741
# Confusion matrix shape: (10, 10)
# Epoch 5 | Loss: 0.7438 | Accuracy: 0.7323 | FPR: 0.0354 | FNR: 0.5576
# Confusion matrix shape: (10, 10)
# Epoch 6 | Loss: 0.6646 | Accuracy: 0.7711 | FPR: 0.0301 | FNR: 0.4719
# Confusion matrix shape: (10, 10)
# Epoch 7 | Loss: 0.6020 | Accuracy: 0.8050 | FPR: 0.0253 | FNR: 0.3573
# Confusion matrix shape: (10, 10)
# Epoch 8 | Loss: 0.5628 | Accuracy: 0.8272 | FPR: 0.0221 | FNR: 0.2786
# Confusion matrix shape: (10, 10)
# Epoch 9 | Loss: 0.5223 | Accuracy: 0.8422 | FPR: 0.0201 | FNR: 0.2401
# Confusion matrix shape: (10, 10)
# Epoch 10 | Loss: 0.4819 | Accuracy: 0.8549 | FPR: 0.0187 | FNR: 0.2178
# Confusion matrix shape: (10, 10)
# Epoch 11 | Loss: 0.4638 | Accuracy: 0.8578 | FPR: 0.0184 | FNR: 0.2146
# Confusion matrix shape: (10, 10)
# Epoch 12 | Loss: 0.4407 | Accuracy: 0.8663 | FPR: 0.0174 | FNR: 0.1976
# Confusion matrix shape: (10, 10)
# Epoch 13 | Loss: 0.4241 | Accuracy: 0.8706 | FPR: 0.0168 | FNR: 0.1749
# Confusion matrix shape: (10, 10)
# Epoch 14 | Loss: 0.4055 | Accuracy: 0.8739 | FPR: 0.0163 | FNR: 0.1638
# Confusion matrix shape: (10, 10)
# Epoch 15 | Loss: 0.3950 | Accuracy: 0.8778 | FPR: 0.0159 | FNR: 0.1598
# Confusion matrix shape: (10, 10)
# Epoch 16 | Loss: 0.3780 | Accuracy: 0.8786 | FPR: 0.0159 | FNR: 0.1712
# Confusion matrix shape: (10, 10)
# Epoch 17 | Loss: 0.3662 | Accuracy: 0.8832 | FPR: 0.0152 | FNR: 0.1631
# Confusion matrix shape: (10, 10)
# Epoch 18 | Loss: 0.3549 | Accuracy: 0.8819 | FPR: 0.0154 | FNR: 0.1519
# Confusion matrix shape: (10, 10)
# Epoch 19 | Loss: 0.3468 | Accuracy: 0.8860 | FPR: 0.0149 | FNR: 0.1445
# Confusion matrix shape: (10, 10)
# Epoch 20 | Loss: 0.3326 | Accuracy: 0.8847 | FPR: 0.0150 | FNR: 0.1502
# Confusion matrix shape: (10, 10)
# Epoch 21 | Loss: 0.3318 | Accuracy: 0.8886 | FPR: 0.0146 | FNR: 0.1523
# Confusion matrix shape: (10, 10)
# Epoch 22 | Loss: 0.3170 | Accuracy: 0.8909 | FPR: 0.0142 | FNR: 0.1432
# Confusion matrix shape: (10, 10)
# Epoch 23 | Loss: 0.3103 | Accuracy: 0.8922 | FPR: 0.0140 | FNR: 0.1299
# Confusion matrix shape: (10, 10)
# Epoch 24 | Loss: 0.3055 | Accuracy: 0.8959 | FPR: 0.0135 | FNR: 0.1285
# Confusion matrix shape: (10, 10)
# Epoch 25 | Loss: 0.2987 | Accuracy: 0.8966 | FPR: 0.0134 | FNR: 0.1333
# Confusion matrix shape: (10, 10)
# Epoch 26 | Loss: 0.2897 | Accuracy: 0.8989 | FPR: 0.0132 | FNR: 0.1268
# Confusion matrix shape: (10, 10)
# Epoch 27 | Loss: 0.2806 | Accuracy: 0.8999 | FPR: 0.0130 | FNR: 0.1183
# Confusion matrix shape: (10, 10)
# Epoch 28 | Loss: 0.2748 | Accuracy: 0.8995 | FPR: 0.0131 | FNR: 0.1233
# Confusion matrix shape: (10, 10)
# Epoch 29 | Loss: 0.2669 | Accuracy: 0.9002 | FPR: 0.0130 | FNR: 0.1241
# Confusion matrix shape: (10, 10)
# Epoch 30 | Loss: 0.2666 | Accuracy: 0.9007 | FPR: 0.0129 | FNR: 0.1143
# Confusion matrix shape: (10, 10)
# Epoch 31 | Loss: 0.2573 | Accuracy: 0.9020 | FPR: 0.0128 | FNR: 0.1151
# Confusion matrix shape: (10, 10)
# Epoch 32 | Loss: 0.2521 | Accuracy: 0.9031 | FPR: 0.0125 | FNR: 0.1148
# Confusion matrix shape: (10, 10)
# Epoch 33 | Loss: 0.2457 | Accuracy: 0.9058 | FPR: 0.0121 | FNR: 0.1127
# Confusion matrix shape: (10, 10)
# Epoch 34 | Loss: 0.2401 | Accuracy: 0.9066 | FPR: 0.0121 | FNR: 0.1082
# Confusion matrix shape: (10, 10)
# Epoch 35 | Loss: 0.2336 | Accuracy: 0.9039 | FPR: 0.0125 | FNR: 0.1109
# Confusion matrix shape: (10, 10)
# Epoch 36 | Loss: 0.2275 | Accuracy: 0.9087 | FPR: 0.0118 | FNR: 0.1093
# Confusion matrix shape: (10, 10)
# Epoch 37 | Loss: 0.2230 | Accuracy: 0.9068 | FPR: 0.0120 | FNR: 0.1051
# Confusion matrix shape: (10, 10)
# Epoch 38 | Loss: 0.2090 | Accuracy: 0.9100 | FPR: 0.0117 | FNR: 0.1094
# Confusion matrix shape: (10, 10)
# Epoch 39 | Loss: 0.2161 | Accuracy: 0.9031 | FPR: 0.0124 | FNR: 0.1223
# Confusion matrix shape: (10, 10)
# Epoch 40 | Loss: 0.2094 | Accuracy: 0.9023 | FPR: 0.0125 | FNR: 0.1074
# Confusion matrix shape: (10, 10)
# Epoch 41 | Loss: 0.1977 | Accuracy: 0.9088 | FPR: 0.0116 | FNR: 0.1017
# Confusion matrix shape: (10, 10)
# Epoch 42 | Loss: 0.1975 | Accuracy: 0.9058 | FPR: 0.0120 | FNR: 0.1193
# Confusion matrix shape: (10, 10)
# Epoch 43 | Loss: 0.1838 | Accuracy: 0.9074 | FPR: 0.0120 | FNR: 0.1107
# Confusion matrix shape: (10, 10)
# Epoch 44 | Loss: 0.1852 | Accuracy: 0.9071 | FPR: 0.0118 | FNR: 0.1031
# Confusion matrix shape: (10, 10)
# Epoch 45 | Loss: 0.1785 | Accuracy: 0.9084 | FPR: 0.0116 | FNR: 0.1012
# Confusion matrix shape: (10, 10)
# Epoch 46 | Loss: 0.1766 | Accuracy: 0.9065 | FPR: 0.0119 | FNR: 0.1132
# Confusion matrix shape: (10, 10)
# Epoch 47 | Loss: 0.1650 | Accuracy: 0.9079 | FPR: 0.0117 | FNR: 0.0979
# Confusion matrix shape: (10, 10)
# Epoch 48 | Loss: 0.1578 | Accuracy: 0.9050 | FPR: 0.0120 | FNR: 0.1083
# Confusion matrix shape: (10, 10)
# Epoch 49 | Loss: 0.1553 | Accuracy: 0.9072 | FPR: 0.0120 | FNR: 0.1212
# Confusion matrix shape: (10, 10)
# Epoch 50 | Loss: 0.1466 | Accuracy: 0.9091 | FPR: 0.0116 | FNR: 0.1037
# Confusion matrix shape: (10, 10)
# Epoch 72 | Loss: 0.0876 | Accuracy: 0.8991 | FPR: 0.0127 | FNR: 0.1071
# Confusion matrix shape: (10, 10)
# Epoch 73 | Loss: 0.0820 | Accuracy: 0.9043 | FPR: 0.0123 | FNR: 0.1096
# Confusion matrix shape: (10, 10)
# Epoch 74 | Loss: 0.0778 | Accuracy: 0.9027 | FPR: 0.0125 | FNR: 0.1147
# Confusion matrix shape: (10, 10)
# Epoch 75 | Loss: 0.0733 | Accuracy: 0.9043 | FPR: 0.0121 | FNR: 0.1009
# Confusion matrix shape: (10, 10)
# Epoch 76 | Loss: 0.0705 | Accuracy: 0.9033 | FPR: 0.0122 | FNR: 0.0981
# Confusion matrix shape: (10, 10)
# Epoch 77 | Loss: 0.0671 | Accuracy: 0.8999 | FPR: 0.0127 | FNR: 0.1111
# Confusion matrix shape: (10, 10)
# Epoch 78 | Loss: 0.0638 | Accuracy: 0.9063 | FPR: 0.0120 | FNR: 0.1023
# Confusion matrix shape: (10, 10)
# Epoch 79 | Loss: 0.0576 | Accuracy: 0.9087 | FPR: 0.0116 | FNR: 0.0976
# Confusion matrix shape: (10, 10)
# Epoch 80 | Loss: 0.0559 | Accuracy: 0.9040 | FPR: 0.0123 | FNR: 0.1071
# Confusion matrix shape: (10, 10)
# Epoch 81 | Loss: 0.0529 | Accuracy: 0.9036 | FPR: 0.0124 | FNR: 0.1069
# Confusion matrix shape: (10, 10)
# Epoch 82 | Loss: 0.0521 | Accuracy: 0.9063 | FPR: 0.0119 | FNR: 0.1001
# Confusion matrix shape: (10, 10)
# Epoch 83 | Loss: 0.0478 | Accuracy: 0.9039 | FPR: 0.0122 | FNR: 0.1092
# Confusion matrix shape: (10, 10)
# Epoch 84 | Loss: 0.0501 | Accuracy: 0.9013 | FPR: 0.0125 | FNR: 0.1077
# Confusion matrix shape: (10, 10)
# Epoch 85 | Loss: 0.0449 | Accuracy: 0.9001 | FPR: 0.0126 | FNR: 0.1084
# Confusion matrix shape: (10, 10)
# Epoch 86 | Loss: 0.0436 | Accuracy: 0.9005 | FPR: 0.0126 | FNR: 0.1069
# Confusion matrix shape: (10, 10)
# Epoch 87 | Loss: 0.0389 | Accuracy: 0.8998 | FPR: 0.0127 | FNR: 0.1111
# Confusion matrix shape: (10, 10)
# Epoch 88 | Loss: 0.0386 | Accuracy: 0.8997 | FPR: 0.0128 | FNR: 0.1138
# Confusion matrix shape: (10, 10)
# Epoch 89 | Loss: 0.0344 | Accuracy: 0.8991 | FPR: 0.0129 | FNR: 0.1117
# Confusion matrix shape: (10, 10)
# Epoch 90 | Loss: 0.0341 | Accuracy: 0.8982 | FPR: 0.0130 | FNR: 0.1091
# Confusion matrix shape: (10, 10)
# Epoch 91 | Loss: 0.0404 | Accuracy: 0.8965 | FPR: 0.0131 | FNR: 0.1056
# Confusion matrix shape: (10, 10)
# Epoch 92 | Loss: 0.0631 | Accuracy: 0.8892 | FPR: 0.0141 | FNR: 0.1455
# Confusion matrix shape: (10, 10)
# Epoch 93 | Loss: 0.1388 | Accuracy: 0.8787 | FPR: 0.0150 | FNR: 0.1165
# Confusion matrix shape: (10, 10)
# Epoch 94 | Loss: 0.0641 | Accuracy: 0.8914 | FPR: 0.0136 | FNR: 0.1306
# Confusion matrix shape: (10, 10)
# Epoch 95 | Loss: 0.0892 | Accuracy: 0.8847 | FPR: 0.0145 | FNR: 0.1650
# Confusion matrix shape: (10, 10)
# Epoch 96 | Loss: 0.0743 | Accuracy: 0.8917 | FPR: 0.0138 | FNR: 0.1243
# Confusion matrix shape: (10, 10)
# Epoch 97 | Loss: 0.0853 | Accuracy: 0.8877 | FPR: 0.0141 | FNR: 0.1194
# Confusion matrix shape: (10, 10)
# Epoch 98 | Loss: 0.0544 | Accuracy: 0.8898 | FPR: 0.0139 | FNR: 0.1126
# Confusion matrix shape: (10, 10)
# Epoch 99 | Loss: 0.0638 | Accuracy: 0.8892 | FPR: 0.0138 | FNR: 0.1279
# Confusion matrix shape: (10, 10)
# Epoch 100 | Loss: 0.0685 | Accuracy: 0.8851 | FPR: 0.0146 | FNR: 0.1373
# Confusion matrix shape: (10, 10)
# Epoch 101 | Loss: 0.0536 | Accuracy: 0.8896 | FPR: 0.0140 | FNR: 0.1261
# Confusion matrix shape: (10, 10)
# Epoch 102 | Loss: 0.0569 | Accuracy: 0.8918 | FPR: 0.0136 | FNR: 0.1133
# Confusion matrix shape: (10, 10)
# Epoch 103 | Loss: 0.0538 | Accuracy: 0.8963 | FPR: 0.0132 | FNR: 0.1107
# Confusion matrix shape: (10, 10)
# Epoch 104 | Loss: 0.0457 | Accuracy: 0.8982 | FPR: 0.0129 | FNR: 0.1078
# Confusion matrix shape: (10, 10)
# Epoch 105 | Loss: 0.0410 | Accuracy: 0.8967 | FPR: 0.0130 | FNR: 0.1115
# Confusion matrix shape: (10, 10)
# Epoch 106 | Loss: 0.0451 | Accuracy: 0.8966 | FPR: 0.0129 | FNR: 0.1148
# Confusion matrix shape: (10, 10)
# Epoch 107 | Loss: 0.0388 | Accuracy: 0.9001 | FPR: 0.0126 | FNR: 0.1142
# Confusion matrix shape: (10, 10)
# Epoch 108 | Loss: 0.0387 | Accuracy: 0.9011 | FPR: 0.0125 | FNR: 0.1129
# Confusion matrix shape: (10, 10)
# Epoch 109 | Loss: 0.0342 | Accuracy: 0.8981 | FPR: 0.0129 | FNR: 0.1119
# Confusion matrix shape: (10, 10)
# Epoch 110 | Loss: 0.0326 | Accuracy: 0.8962 | FPR: 0.0132 | FNR: 0.1154
# Confusion matrix shape: (10, 10)
# Epoch 111 | Loss: 0.0344 | Accuracy: 0.9002 | FPR: 0.0126 | FNR: 0.1058
# Confusion matrix shape: (10, 10)
# Epoch 112 | Loss: 0.0313 | Accuracy: 0.8979 | FPR: 0.0129 | FNR: 0.1135
# Confusion matrix shape: (10, 10)
# Epoch 113 | Loss: 0.0291 | Accuracy: 0.9017 | FPR: 0.0124 | FNR: 0.1042
# Confusion matrix shape: (10, 10)
# Epoch 114 | Loss: 0.0274 | Accuracy: 0.8972 | FPR: 0.0130 | FNR: 0.1163
# Confusion matrix shape: (10, 10)
# Epoch 115 | Loss: 0.0286 | Accuracy: 0.8976 | FPR: 0.0129 | FNR: 0.1167
# Confusion matrix shape: (10, 10)
# Epoch 116 | Loss: 0.0241 | Accuracy: 0.9034 | FPR: 0.0122 | FNR: 0.1039
# Confusion matrix shape: (10, 10)
# Epoch 117 | Loss: 0.0244 | Accuracy: 0.8979 | FPR: 0.0130 | FNR: 0.1101
# Confusion matrix shape: (10, 10)
# Epoch 118 | Loss: 0.0251 | Accuracy: 0.8985 | FPR: 0.0128 | FNR: 0.1076
# Confusion matrix shape: (10, 10)
# Epoch 119 | Loss: 0.0254 | Accuracy: 0.8998 | FPR: 0.0125 | FNR: 0.1094
# Confusion matrix shape: (10, 10)
# Epoch 120 | Loss: 0.0213 | Accuracy: 0.9020 | FPR: 0.0123 | FNR: 0.1060
# Confusion matrix shape: (10, 10)
# Epoch 121 | Loss: 0.0231 | Accuracy: 0.9004 | FPR: 0.0126 | FNR: 0.1072
# Confusion matrix shape: (10, 10)
# Epoch 122 | Loss: 0.0199 | Accuracy: 0.8966 | FPR: 0.0131 | FNR: 0.1138
# Confusion matrix shape: (10, 10)
# Epoch 123 | Loss: 0.0201 | Accuracy: 0.8994 | FPR: 0.0128 | FNR: 0.1031
# Confusion matrix shape: (10, 10)
# Epoch 124 | Loss: 0.0180 | Accuracy: 0.8963 | FPR: 0.0131 | FNR: 0.1055
# Confusion matrix shape: (10, 10)
# Epoch 125 | Loss: 0.0193 | Accuracy: 0.9021 | FPR: 0.0124 | FNR: 0.1027
# Confusion matrix shape: (10, 10)
# Epoch 126 | Loss: 0.0188 | Accuracy: 0.9024 | FPR: 0.0124 | FNR: 0.1098
# Confusion matrix shape: (10, 10)
# Epoch 127 | Loss: 0.0190 | Accuracy: 0.8994 | FPR: 0.0127 | FNR: 0.1106
# Confusion matrix shape: (10, 10)
# Epoch 128 | Loss: 0.0164 | Accuracy: 0.8978 | FPR: 0.0130 | FNR: 0.1094
# Confusion matrix shape: (10, 10)
# Epoch 129 | Loss: 0.0173 | Accuracy: 0.9008 | FPR: 0.0125 | FNR: 0.1081
# Confusion matrix shape: (10, 10)
# Epoch 130 | Loss: 0.0149 | Accuracy: 0.8975 | FPR: 0.0130 | FNR: 0.1107
# Confusion matrix shape: (10, 10)
# Epoch 131 | Loss: 0.0165 | Accuracy: 0.8959 | FPR: 0.0131 | FNR: 0.1171
# Confusion matrix shape: (10, 10)
# Epoch 132 | Loss: 0.0147 | Accuracy: 0.9010 | FPR: 0.0125 | FNR: 0.1057
# Confusion matrix shape: (10, 10)
# Epoch 133 | Loss: 0.0132 | Accuracy: 0.8985 | FPR: 0.0128 | FNR: 0.1074
# Confusion matrix shape: (10, 10)
# Epoch 134 | Loss: 0.0139 | Accuracy: 0.9042 | FPR: 0.0120 | FNR: 0.1001
# Confusion matrix shape: (10, 10)
# Epoch 135 | Loss: 0.0152 | Accuracy: 0.8973 | FPR: 0.0129 | FNR: 0.1123
# Confusion matrix shape: (10, 10)
# Epoch 136 | Loss: 0.0143 | Accuracy: 0.8994 | FPR: 0.0127 | FNR: 0.1060
# Confusion matrix shape: (10, 10)
# Epoch 137 | Loss: 0.0135 | Accuracy: 0.9034 | FPR: 0.0123 | FNR: 0.0998
# Confusion matrix shape: (10, 10)
# Epoch 138 | Loss: 0.0117 | Accuracy: 0.8981 | FPR: 0.0128 | FNR: 0.1055
# Confusion matrix shape: (10, 10)
# Epoch 139 | Loss: 0.0123 | Accuracy: 0.8975 | FPR: 0.0130 | FNR: 0.1099
# Confusion matrix shape: (10, 10)
# Epoch 140 | Loss: 0.0129 | Accuracy: 0.8998 | FPR: 0.0126 | FNR: 0.1010
# Confusion matrix shape: (10, 10)
# Epoch 141 | Loss: 0.0126 | Accuracy: 0.8985 | FPR: 0.0127 | FNR: 0.1073
# Confusion matrix shape: (10, 10)
# Epoch 142 | Loss: 0.0115 | Accuracy: 0.8995 | FPR: 0.0126 | FNR: 0.1022
# Confusion matrix shape: (10, 10)
# Epoch 143 | Loss: 0.0118 | Accuracy: 0.8992 | FPR: 0.0127 | FNR: 0.1069
# Confusion matrix shape: (10, 10)
# Epoch 144 | Loss: 0.0112 | Accuracy: 0.8983 | FPR: 0.0129 | FNR: 0.1081
# Confusion matrix shape: (10, 10)
# Epoch 145 | Loss: 0.0117 | Accuracy: 0.9020 | FPR: 0.0125 | FNR: 0.1054
# Confusion matrix shape: (10, 10)
# Epoch 146 | Loss: 0.0108 | Accuracy: 0.8995 | FPR: 0.0128 | FNR: 0.1084
# Confusion matrix shape: (10, 10)
# Epoch 147 | Loss: 0.0122 | Accuracy: 0.8999 | FPR: 0.0126 | FNR: 0.1061
# Confusion matrix shape: (10, 10)
# Epoch 148 | Loss: 0.0106 | Accuracy: 0.9015 | FPR: 0.0124 | FNR: 0.1033
# Confusion matrix shape: (10, 10)
# Epoch 149 | Loss: 0.0090 | Accuracy: 0.9002 | FPR: 0.0126 | FNR: 0.1057
# Confusion matrix shape: (10, 10)
# Epoch 150 | Loss: 0.0108 | Accuracy: 0.8969 | FPR: 0.0130 | FNR: 0.1108
# Confusion matrix shape: (10, 10)
# Epoch 151 | Loss: 0.0099 | Accuracy: 0.8982 | FPR: 0.0128 | FNR: 0.1092
# Confusion matrix shape: (10, 10)
# Epoch 152 | Loss: 0.0099 | Accuracy: 0.8973 | FPR: 0.0129 | FNR: 0.1090
# Confusion matrix shape: (10, 10)
# Epoch 153 | Loss: 0.0098 | Accuracy: 0.8978 | FPR: 0.0128 | FNR: 0.1062
# Confusion matrix shape: (10, 10)
# Epoch 154 | Loss: 0.0098 | Accuracy: 0.8982 | FPR: 0.0129 | FNR: 0.1077
# Confusion matrix shape: (10, 10)
# Epoch 155 | Loss: 0.0100 | Accuracy: 0.8998 | FPR: 0.0127 | FNR: 0.1090
# Confusion matrix shape: (10, 10)
# Epoch 156 | Loss: 0.0090 | Accuracy: 0.8999 | FPR: 0.0126 | FNR: 0.1047
# Confusion matrix shape: (10, 10)
# Epoch 157 | Loss: 0.0092 | Accuracy: 0.8989 | FPR: 0.0127 | FNR: 0.1054
# Confusion matrix shape: (10, 10)
# Epoch 158 | Loss: 0.0096 | Accuracy: 0.8989 | FPR: 0.0128 | FNR: 0.1076
# Confusion matrix shape: (10, 10)
# Epoch 159 | Loss: 0.0075 | Accuracy: 0.9005 | FPR: 0.0125 | FNR: 0.1021
# Confusion matrix shape: (10, 10)
# Epoch 160 | Loss: 0.0084 | Accuracy: 0.9008 | FPR: 0.0125 | FNR: 0.1013
# Confusion matrix shape: (10, 10)
# Epoch 161 | Loss: 0.0099 | Accuracy: 0.8981 | FPR: 0.0129 | FNR: 0.1081
# Confusion matrix shape: (10, 10)
# Epoch 162 | Loss: 0.0079 | Accuracy: 0.8991 | FPR: 0.0127 | FNR: 0.1061
# Confusion matrix shape: (10, 10)
# Epoch 163 | Loss: 0.0087 | Accuracy: 0.8989 | FPR: 0.0126 | FNR: 0.1064
# Confusion matrix shape: (10, 10)
# Epoch 164 | Loss: 0.0084 | Accuracy: 0.8992 | FPR: 0.0126 | FNR: 0.1082
# Confusion matrix shape: (10, 10)
# Epoch 165 | Loss: 0.0072 | Accuracy: 0.9015 | FPR: 0.0124 | FNR: 0.1077
# Confusion matrix shape: (10, 10)
# Epoch 166 | Loss: 0.0068 | Accuracy: 0.8963 | FPR: 0.0130 | FNR: 0.1099
# Confusion matrix shape: (10, 10)
# Epoch 167 | Loss: 0.0088 | Accuracy: 0.8959 | FPR: 0.0131 | FNR: 0.1121
# Confusion matrix shape: (10, 10)
# Epoch 168 | Loss: 0.0077 | Accuracy: 0.8989 | FPR: 0.0127 | FNR: 0.1075
# Confusion matrix shape: (10, 10)
# Epoch 169 | Loss: 0.0076 | Accuracy: 0.8982 | FPR: 0.0128 | FNR: 0.1088
# Confusion matrix shape: (10, 10)
# Epoch 170 | Loss: 0.0079 | Accuracy: 0.8995 | FPR: 0.0126 | FNR: 0.1075
# Confusion matrix shape: (10, 10)
# Epoch 171 | Loss: 0.0074 | Accuracy: 0.8995 | FPR: 0.0126 | FNR: 0.1077
# Confusion matrix shape: (10, 10)
# Epoch 172 | Loss: 0.0078 | Accuracy: 0.8965 | FPR: 0.0130 | FNR: 0.1101
# Confusion matrix shape: (10, 10)
# Epoch 173 | Loss: 0.0080 | Accuracy: 0.8981 | FPR: 0.0129 | FNR: 0.1118
# Confusion matrix shape: (10, 10)
# Epoch 174 | Loss: 0.0069 | Accuracy: 0.8994 | FPR: 0.0127 | FNR: 0.1083
# Confusion matrix shape: (10, 10)
# Epoch 175 | Loss: 0.0067 | Accuracy: 0.8950 | FPR: 0.0132 | FNR: 0.1157
# Confusion matrix shape: (10, 10)
# Epoch 176 | Loss: 0.0073 | Accuracy: 0.8947 | FPR: 0.0133 | FNR: 0.1155
# Confusion matrix shape: (10, 10)
# Epoch 177 | Loss: 0.0071 | Accuracy: 0.8995 | FPR: 0.0126 | FNR: 0.1058
# Confusion matrix shape: (10, 10)
# Confusion matrix shape: (10, 10)
# Epoch 200 | Loss: 0.0063 | Accuracy: 0.8975 | FPR: 0.0128 | FNR: 0.1092
# Confusion matrix shape: (10, 10)
# Epoch 201 | Loss: 0.0063 | Accuracy: 0.8978 | FPR: 0.0129 | FNR: 0.1114
# Confusion matrix shape: (10, 10)
# Epoch 202 | Loss: 0.0060 | Accuracy: 0.8978 | FPR: 0.0128 | FNR: 0.1031
# Confusion matrix shape: (10, 10)
# Epoch 203 | Loss: 0.0057 | Accuracy: 0.8983 | FPR: 0.0127 | FNR: 0.1069
# Confusion matrix shape: (10, 10)
# Epoch 204 | Loss: 0.0056 | Accuracy: 0.9007 | FPR: 0.0125 | FNR: 0.1029
# Confusion matrix shape: (10, 10)
# Epoch 205 | Loss: 0.0052 | Accuracy: 0.8999 | FPR: 0.0125 | FNR: 0.1043
# Confusion matrix shape: (10, 10)
# Epoch 206 | Loss: 0.0058 | Accuracy: 0.8978 | FPR: 0.0128 | FNR: 0.1091
# Confusion matrix shape: (10, 10)
# Epoch 207 | Loss: 0.0057 | Accuracy: 0.9021 | FPR: 0.0123 | FNR: 0.1036
# Confusion matrix shape: (10, 10)
# Epoch 208 | Loss: 0.0047 | Accuracy: 0.8989 | FPR: 0.0126 | FNR: 0.1090
# Confusion matrix shape: (10, 10)
# Epoch 209 | Loss: 0.0057 | Accuracy: 0.9011 | FPR: 0.0124 | FNR: 0.1076
# Confusion matrix shape: (10, 10)
# Epoch 210 | Loss: 0.0053 | Accuracy: 0.8966 | FPR: 0.0129 | FNR: 0.1073
# Confusion matrix shape: (10, 10)
# Epoch 211 | Loss: 0.0055 | Accuracy: 0.9014 | FPR: 0.0123 | FNR: 0.1031
# Confusion matrix shape: (10, 10)
# Epoch 212 | Loss: 0.0051 | Accuracy: 0.8982 | FPR: 0.0128 | FNR: 0.1098
# Confusion matrix shape: (10, 10)
# Epoch 213 | Loss: 0.0047 | Accuracy: 0.8981 | FPR: 0.0128 | FNR: 0.1101
# Confusion matrix shape: (10, 10)
# Epoch 214 | Loss: 0.0055 | Accuracy: 0.8985 | FPR: 0.0126 | FNR: 0.1043
# Confusion matrix shape: (10, 10)
# Epoch 215 | Loss: 0.0048 | Accuracy: 0.9010 | FPR: 0.0124 | FNR: 0.1032
# Confusion matrix shape: (10, 10)
# Epoch 216 | Loss: 0.0045 | Accuracy: 0.8986 | FPR: 0.0127 | FNR: 0.1085
# Confusion matrix shape: (10, 10)
# Epoch 217 | Loss: 0.0050 | Accuracy: 0.8985 | FPR: 0.0128 | FNR: 0.1072
# Confusion matrix shape: (10, 10)
# Epoch 218 | Loss: 0.0049 | Accuracy: 0.9013 | FPR: 0.0125 | FNR: 0.1044
# Confusion matrix shape: (10, 10)
# Epoch 219 | Loss: 0.0045 | Accuracy: 0.8983 | FPR: 0.0128 | FNR: 0.1103
# Confusion matrix shape: (10, 10)
# Epoch 220 | Loss: 0.0047 | Accuracy: 0.8985 | FPR: 0.0127 | FNR: 0.1021
# Confusion matrix shape: (10, 10)
# Epoch 221 | Loss: 0.0047 | Accuracy: 0.8975 | FPR: 0.0129 | FNR: 0.1066
# Confusion matrix shape: (10, 10)
# Epoch 222 | Loss: 0.0052 | Accuracy: 0.9023 | FPR: 0.0122 | FNR: 0.1007
# Confusion matrix shape: (10, 10)
# Epoch 223 | Loss: 0.0052 | Accuracy: 0.9002 | FPR: 0.0125 | FNR: 0.1010
# Confusion matrix shape: (10, 10)
# Epoch 224 | Loss: 0.0049 | Accuracy: 0.8978 | FPR: 0.0128 | FNR: 0.1019
# Confusion matrix shape: (10, 10)
# Epoch 225 | Loss: 0.0054 | Accuracy: 0.8995 | FPR: 0.0126 | FNR: 0.1030
# Confusion matrix shape: (10, 10)
# Epoch 226 | Loss: 0.0052 | Accuracy: 0.8988 | FPR: 0.0128 | FNR: 0.1066
# Confusion matrix shape: (10, 10)
# Epoch 227 | Loss: 0.0044 | Accuracy: 0.9018 | FPR: 0.0124 | FNR: 0.1045
# Confusion matrix shape: (10, 10)
# Epoch 228 | Loss: 0.0052 | Accuracy: 0.8992 | FPR: 0.0127 | FNR: 0.1087
# Confusion matrix shape: (10, 10)
# Epoch 229 | Loss: 0.0046 | Accuracy: 0.8972 | FPR: 0.0129 | FNR: 0.1079
# Confusion matrix shape: (10, 10)
# Epoch 230 | Loss: 0.0051 | Accuracy: 0.8979 | FPR: 0.0128 | FNR: 0.1067
# Confusion matrix shape: (10, 10)
# Epoch 231 | Loss: 0.0047 | Accuracy: 0.8992 | FPR: 0.0126 | FNR: 0.1064
# Confusion matrix shape: (10, 10)
# Epoch 232 | Loss: 0.0045 | Accuracy: 0.8985 | FPR: 0.0127 | FNR: 0.1048
# Confusion matrix shape: (10, 10)
# Epoch 233 | Loss: 0.0043 | Accuracy: 0.8988 | FPR: 0.0127 | FNR: 0.1052
# Confusion matrix shape: (10, 10)
# Epoch 234 | Loss: 0.0046 | Accuracy: 0.8989 | FPR: 0.0128 | FNR: 0.1097
# Confusion matrix shape: (10, 10)
# Epoch 235 | Loss: 0.0052 | Accuracy: 0.8997 | FPR: 0.0126 | FNR: 0.1061
# Confusion matrix shape: (10, 10)
# Epoch 236 | Loss: 0.0047 | Accuracy: 0.9004 | FPR: 0.0124 | FNR: 0.1061
# Confusion matrix shape: (10, 10)
# Epoch 237 | Loss: 0.0050 | Accuracy: 0.8981 | FPR: 0.0128 | FNR: 0.1075
# Confusion matrix shape: (10, 10)
# Epoch 238 | Loss: 0.0045 | Accuracy: 0.8995 | FPR: 0.0126 | FNR: 0.1078
# Confusion matrix shape: (10, 10)
# Epoch 239 | Loss: 0.0044 | Accuracy: 0.8979 | FPR: 0.0128 | FNR: 0.1045
# Confusion matrix shape: (10, 10)
# Epoch 240 | Loss: 0.0047 | Accuracy: 0.8986 | FPR: 0.0127 | FNR: 0.1065
# Confusion matrix shape: (10, 10)
# Epoch 241 | Loss: 0.0053 | Accuracy: 0.8991 | FPR: 0.0127 | FNR: 0.1029
# Confusion matrix shape: (10, 10)
# Epoch 242 | Loss: 0.0052 | Accuracy: 0.8997 | FPR: 0.0126 | FNR: 0.1055
# Confusion matrix shape: (10, 10)
# Epoch 243 | Loss: 0.0042 | Accuracy: 0.8976 | FPR: 0.0127 | FNR: 0.1051
# Confusion matrix shape: (10, 10)
# Epoch 244 | Loss: 0.0046 | Accuracy: 0.8998 | FPR: 0.0126 | FNR: 0.1002
# Confusion matrix shape: (10, 10)
# Epoch 245 | Loss: 0.0052 | Accuracy: 0.8989 | FPR: 0.0126 | FNR: 0.1011
# Confusion matrix shape: (10, 10)
# Epoch 246 | Loss: 0.0045 | Accuracy: 0.9002 | FPR: 0.0124 | FNR: 0.1018
# Confusion matrix shape: (10, 10)
# Epoch 247 | Loss: 0.0045 | Accuracy: 0.8976 | FPR: 0.0129 | FNR: 0.1110
# Confusion matrix shape: (10, 10)
# Epoch 248 | Loss: 0.0043 | Accuracy: 0.8991 | FPR: 0.0128 | FNR: 0.1059
# Confusion matrix shape: (10, 10)
# Epoch 249 | Loss: 0.0046 | Accuracy: 0.8986 | FPR: 0.0128 | FNR: 0.1045
# Confusion matrix shape: (10, 10)
# Epoch 250 | Loss: 0.0046 | Accuracy: 0.8995 | FPR: 0.0126 | FNR: 0.1038
# Confusion matrix shape: (10, 10)
# Epoch 251 | Loss: 0.0047 | Accuracy: 0.8989 | FPR: 0.0127 | FNR: 0.1051
# Confusion matrix shape: (10, 10)
# Epoch 252 | Loss: 0.0038 | Accuracy: 0.8979 | FPR: 0.0127 | FNR: 0.1071
# Confusion matrix shape: (10, 10)
# Epoch 253 | Loss: 0.0050 | Accuracy: 0.9005 | FPR: 0.0125 | FNR: 0.1046
# Confusion matrix shape: (10, 10)
# Epoch 254 | Loss: 0.0047 | Accuracy: 0.8970 | FPR: 0.0130 | FNR: 0.1120
# Confusion matrix shape: (10, 10)
# Epoch 255 | Loss: 0.0040 | Accuracy: 0.8963 | FPR: 0.0130 | FNR: 0.1078
# Confusion matrix shape: (10, 10)
# Epoch 256 | Loss: 0.0039 | Accuracy: 0.8997 | FPR: 0.0125 | FNR: 0.1039
# Confusion matrix shape: (10, 10)
# Epoch 257 | Loss: 0.0045 | Accuracy: 0.8982 | FPR: 0.0128 | FNR: 0.1066
# Confusion matrix shape: (10, 10)
# Epoch 258 | Loss: 0.0041 | Accuracy: 0.8986 | FPR: 0.0127 | FNR: 0.1078
# Confusion matrix shape: (10, 10)
# Epoch 259 | Loss: 0.0045 | Accuracy: 0.8988 | FPR: 0.0127 | FNR: 0.1059
# Confusion matrix shape: (10, 10)
# Epoch 260 | Loss: 0.0036 | Accuracy: 0.8978 | FPR: 0.0128 | FNR: 0.1041
# Confusion matrix shape: (10, 10)
# Epoch 261 | Loss: 0.0043 | Accuracy: 0.9018 | FPR: 0.0123 | FNR: 0.0999
# Confusion matrix shape: (10, 10)
# Epoch 262 | Loss: 0.0038 | Accuracy: 0.9023 | FPR: 0.0123 | FNR: 0.1032
# Confusion matrix shape: (10, 10)
# Epoch 263 | Loss: 0.0040 | Accuracy: 0.9005 | FPR: 0.0125 | FNR: 0.1056
# Confusion matrix shape: (10, 10)
# Epoch 264 | Loss: 0.0041 | Accuracy: 0.8997 | FPR: 0.0126 | FNR: 0.1082
# Confusion matrix shape: (10, 10)
# Epoch 265 | Loss: 0.0046 | Accuracy: 0.9014 | FPR: 0.0123 | FNR: 0.1054
# Confusion matrix shape: (10, 10)
# Epoch 266 | Loss: 0.0039 | Accuracy: 0.8997 | FPR: 0.0125 | FNR: 0.1043
# Confusion matrix shape: (10, 10)
# Epoch 267 | Loss: 0.0040 | Accuracy: 0.9008 | FPR: 0.0123 | FNR: 0.1019
# Confusion matrix shape: (10, 10)
# Epoch 268 | Loss: 0.0044 | Accuracy: 0.8969 | FPR: 0.0130 | FNR: 0.1092
# Confusion matrix shape: (10, 10)
# Epoch 269 | Loss: 0.0041 | Accuracy: 0.9026 | FPR: 0.0122 | FNR: 0.1016
# Confusion matrix shape: (10, 10)
# Epoch 270 | Loss: 0.0037 | Accuracy: 0.9004 | FPR: 0.0126 | FNR: 0.0990
# Confusion matrix shape: (10, 10)
# Epoch 271 | Loss: 0.0037 | Accuracy: 0.9002 | FPR: 0.0125 | FNR: 0.1019
# Confusion matrix shape: (10, 10)
# Epoch 272 | Loss: 0.0033 | Accuracy: 0.8997 | FPR: 0.0125 | FNR: 0.1040
# Confusion matrix shape: (10, 10)
# Epoch 273 | Loss: 0.0039 | Accuracy: 0.9001 | FPR: 0.0125 | FNR: 0.1060
# Confusion matrix shape: (10, 10)
# Epoch 274 | Loss: 0.0036 | Accuracy: 0.9013 | FPR: 0.0123 | FNR: 0.1037
# Confusion matrix shape: (10, 10)
# Epoch 275 | Loss: 0.0034 | Accuracy: 0.9002 | FPR: 0.0124 | FNR: 0.1039
# Confusion matrix shape: (10, 10)
# Epoch 276 | Loss: 0.0034 | Accuracy: 0.9015 | FPR: 0.0123 | FNR: 0.1043
# Confusion matrix shape: (10, 10)
# Epoch 277 | Loss: 0.0035 | Accuracy: 0.9001 | FPR: 0.0125 | FNR: 0.1030
# Confusion matrix shape: (10, 10)
# Epoch 278 | Loss: 0.0034 | Accuracy: 0.8991 | FPR: 0.0126 | FNR: 0.1073
# Confusion matrix shape: (10, 10)
# Epoch 279 | Loss: 0.0035 | Accuracy: 0.9001 | FPR: 0.0125 | FNR: 0.1042
# Confusion matrix shape: (10, 10)
# Epoch 280 | Loss: 0.0033 | Accuracy: 0.9004 | FPR: 0.0125 | FNR: 0.1005
# Confusion matrix shape: (10, 10)
# Epoch 281 | Loss: 0.0034 | Accuracy: 0.8981 | FPR: 0.0127 | FNR: 0.1053
# Confusion matrix shape: (10, 10)
# Epoch 282 | Loss: 0.0033 | Accuracy: 0.9005 | FPR: 0.0124 | FNR: 0.1050
# Confusion matrix shape: (10, 10)
# Epoch 283 | Loss: 0.0038 | Accuracy: 0.8989 | FPR: 0.0126 | FNR: 0.1066
# Confusion matrix shape: (10, 10)
# Epoch 241 | Loss: 0.8645 | Accuracy: 0.7363 | FPR: 0.0368 | FNR: 0.3938
# Confusion matrix shape: (10, 10)
# Epoch 242 | Loss: 0.8732 | Accuracy: 0.7333 | FPR: 0.0372 | FNR: 0.3902
# Confusion matrix shape: (10, 10)
# Epoch 243 | Loss: 0.8519 | Accuracy: 0.7352 | FPR: 0.0367 | FNR: 0.3961
# Confusion matrix shape: (10, 10)
# Epoch 244 | Loss: 0.8910 | Accuracy: 0.7266 | FPR: 0.0386 | FNR: 0.4036
# Confusion matrix shape: (10, 10)
# Epoch 245 | Loss: 0.8435 | Accuracy: 0.7411 | FPR: 0.0360 | FNR: 0.3852
# Confusion matrix shape: (10, 10)
# Epoch 246 | Loss: 0.8318 | Accuracy: 0.7384 | FPR: 0.0362 | FNR: 0.3961
# Confusion matrix shape: (10, 10)
# Epoch 247 | Loss: 0.8395 | Accuracy: 0.7373 | FPR: 0.0362 | FNR: 0.3914
# Confusion matrix shape: (10, 10)
# Epoch 248 | Loss: 0.8421 | Accuracy: 0.7408 | FPR: 0.0358 | FNR: 0.3840
# Confusion matrix shape: (10, 10)
# Epoch 249 | Loss: 0.8309 | Accuracy: 0.7359 | FPR: 0.0363 | FNR: 0.3824
# Confusion matrix shape: (10, 10)
# Epoch 250 | Loss: 0.8488 | Accuracy: 0.7279 | FPR: 0.0376 | FNR: 0.3821
# Confusion matrix shape: (10, 10)
# Epoch 251 | Loss: 0.8816 | Accuracy: 0.7216 | FPR: 0.0376 | FNR: 0.3842
# Confusion matrix shape: (10, 10)
# Epoch 252 | Loss: 0.8518 | Accuracy: 0.7405 | FPR: 0.0357 | FNR: 0.3755
# Confusion matrix shape: (10, 10)
# Epoch 253 | Loss: 0.8690 | Accuracy: 0.7238 | FPR: 0.0384 | FNR: 0.3974
# Confusion matrix shape: (10, 10)
# Epoch 254 | Loss: 0.8333 | Accuracy: 0.7378 | FPR: 0.0365 | FNR: 0.3913
# Confusion matrix shape: (10, 10)
# Epoch 255 | Loss: 0.8301 | Accuracy: 0.7389 | FPR: 0.0363 | FNR: 0.3992
# Confusion matrix shape: (10, 10)
# Epoch 256 | Loss: 0.8379 | Accuracy: 0.7371 | FPR: 0.0366 | FNR: 0.4018
# Confusion matrix shape: (10, 10)
# Epoch 257 | Loss: 0.8301 | Accuracy: 0.7379 | FPR: 0.0362 | FNR: 0.4052
# Confusion matrix shape: (10, 10)
# Epoch 258 | Loss: 0.8279 | Accuracy: 0.7369 | FPR: 0.0363 | FNR: 0.4068
# Confusion matrix shape: (10, 10)
# Epoch 259 | Loss: 0.8198 | Accuracy: 0.7446 | FPR: 0.0355 | FNR: 0.3825
# Confusion matrix shape: (10, 10)
# Epoch 260 | Loss: 0.8288 | Accuracy: 0.7392 | FPR: 0.0363 | FNR: 0.3845
# Confusion matrix shape: (10, 10)
# Epoch 261 | Loss: 0.8302 | Accuracy: 0.7387 | FPR: 0.0361 | FNR: 0.3737
# Confusion matrix shape: (10, 10)
# Epoch 262 | Loss: 0.8162 | Accuracy: 0.7472 | FPR: 0.0349 | FNR: 0.3692
# Confusion matrix shape: (10, 10)
# Epoch 284 | Loss: 0.8151 | Accuracy: 0.7392 | FPR: 0.0361 | FNR: 0.3818
# Confusion matrix shape: (10, 10)
# Epoch 285 | Loss: 0.8232 | Accuracy: 0.7404 | FPR: 0.0363 | FNR: 0.3793
# Confusion matrix shape: (10, 10)
# Epoch 286 | Loss: 0.8401 | Accuracy: 0.7405 | FPR: 0.0360 | FNR: 0.3928
# Confusion matrix shape: (10, 10)
# Epoch 287 | Loss: 0.8354 | Accuracy: 0.7437 | FPR: 0.0357 | FNR: 0.3810
# Confusion matrix shape: (10, 10)
# Epoch 288 | Loss: 0.8381 | Accuracy: 0.7433 | FPR: 0.0354 | FNR: 0.4043
# Confusion matrix shape: (10, 10)
# Epoch 289 | Loss: 0.8287 | Accuracy: 0.7394 | FPR: 0.0357 | FNR: 0.3928
# Confusion matrix shape: (10, 10)
# Epoch 290 | Loss: 0.8074 | Accuracy: 0.7407 | FPR: 0.0356 | FNR: 0.3892
# Confusion matrix shape: (10, 10)
# Epoch 291 | Loss: 0.8177 | Accuracy: 0.7416 | FPR: 0.0352 | FNR: 0.3716
# Confusion matrix shape: (10, 10)
# Epoch 292 | Loss: 0.8104 | Accuracy: 0.7475 | FPR: 0.0348 | FNR: 0.3630
# Confusion matrix shape: (10, 10)
# Epoch 293 | Loss: 0.8058 | Accuracy: 0.7453 | FPR: 0.0350 | FNR: 0.3656
# Confusion matrix shape: (10, 10)
# Epoch 294 | Loss: 0.7997 | Accuracy: 0.7462 | FPR: 0.0349 | FNR: 0.3632
# Confusion matrix shape: (10, 10)
# Epoch 295 | Loss: 0.8010 | Accuracy: 0.7458 | FPR: 0.0350 | FNR: 0.3725
# Confusion matrix shape: (10, 10)
# Epoch 296 | Loss: 0.7929 | Accuracy: 0.7442 | FPR: 0.0351 | FNR: 0.3694
# Confusion matrix shape: (10, 10)
# Epoch 297 | Loss: 0.7965 | Accuracy: 0.7421 | FPR: 0.0353 | FNR: 0.3783
# Confusion matrix shape: (10, 10)
# Epoch 298 | Loss: 0.8073 | Accuracy: 0.7421 | FPR: 0.0353 | FNR: 0.3860
# Confusion matrix shape: (10, 10)
# Epoch 299 | Loss: 0.8189 | Accuracy: 0.7372 | FPR: 0.0363 | FNR: 0.3880
# Confusion matrix shape: (10, 10)
# Epoch 300 | Loss: 0.7915 | Accuracy: 0.7451 | FPR: 0.0351 | FNR: 0.3850
# Confusion matrix shape: (10, 10)
# Epoch 301 | Loss: 0.8151 | Accuracy: 0.7368 | FPR: 0.0364 | FNR: 0.3821
# Confusion matrix shape: (10, 10)
# Epoch 302 | Loss: 0.8128 | Accuracy: 0.7442 | FPR: 0.0353 | FNR: 0.3756
# Confusion matrix shape: (10, 10)
# Epoch 303 | Loss: 0.7954 | Accuracy: 0.7483 | FPR: 0.0349 | FNR: 0.3646
# Confusion matrix shape: (10, 10)
# Epoch 304 | Loss: 0.8098 | Accuracy: 0.7462 | FPR: 0.0352 | FNR: 0.3691
# Confusion matrix shape: (10, 10)
# Epoch 369 | Loss: 0.7807 | Accuracy: 0.7452 | FPR: 0.0353 | FNR: 0.3861
# Confusion matrix shape: (10, 10)
# Epoch 370 | Loss: 0.7757 | Accuracy: 0.7526 | FPR: 0.0339 | FNR: 0.3569
# Confusion matrix shape: (10, 10)
# Epoch 371 | Loss: 0.7852 | Accuracy: 0.7442 | FPR: 0.0351 | FNR: 0.3686
# Confusion matrix shape: (10, 10)
# Epoch 372 | Loss: 0.8192 | Accuracy: 0.7426 | FPR: 0.0357 | FNR: 0.3699
# Confusion matrix shape: (10, 10)
# Epoch 373 | Loss: 0.7854 | Accuracy: 0.7456 | FPR: 0.0349 | FNR: 0.3630
# Confusion matrix shape: (10, 10)
# Epoch 374 | Loss: 0.7977 | Accuracy: 0.7442 | FPR: 0.0350 | FNR: 0.3726
# Confusion matrix shape: (10, 10)
# Epoch 375 | Loss: 0.7860 | Accuracy: 0.7468 | FPR: 0.0347 | FNR: 0.3786
# Early stopping triggered.

# %%
# Summarize results in a readable format
for dataset_name, dataset_results in results.items():
    print(f"\nSummary for {dataset_name}:")
    print(f"{'Setting':<15}{'Mask Ratio':<15}{'Architecture':<15}{'Accuracy':<10}{'FPR':<10}{'FNR':<10}")
    print("-" * 65)
    for result in dataset_results:
        print(f"{result['setting']:<15}{result['mask_ratio']:<15}{result['architecture']:<15}{result['accuracy']:<10}{result['false_positive_rate']:<10}{result['false_negative_rate']:<10}")
# Out:
# Summary for Cora:
# Setting        Mask Ratio     Architecture   Accuracy  FPR       FNR
# -----------------------------------------------------------------
# transductive   0.0            GCN            0.8029    0.0348    0.2001
# transductive   0.0            GAT            0.8048    0.0342    0.2074
# transductive   0.0            SAGE           0.8232    0.0314    0.184
# transductive   0.0            GIN            0.7845    0.038     0.2321
# transductive   0.05           GCN            0.8158    0.0321    0.1839
# transductive   0.05           GAT            0.8177    0.0317    0.1932
# transductive   0.05           SAGE           0.8379    0.0284    0.1825
# transductive   0.05           GIN            0.7864    0.0374    0.2332
# transductive   0.1            GCN            0.8195    0.0319    0.18
# transductive   0.1            GAT            0.8379    0.0286    0.1741
# transductive   0.1            SAGE           0.8435    0.0277    0.1646
# transductive   0.1            GIN            0.7643    0.0415    0.2484
# transductive   0.2            GCN            0.8103    0.0338    0.1928
# transductive   0.2            GAT            0.8029    0.0353    0.2127
# transductive   0.2            SAGE           0.8269    0.0307    0.1845
# transductive   0.2            GIN            0.7495    0.0443    0.2678
# inductive      0.0            GCN            0.8161    0.0319    0.1972
# inductive      0.0            GAT            0.808     0.033     0.2035
# inductive      0.0            SAGE           0.8168    0.0313    0.1915
# inductive      0.0            GIN            0.771     0.0394    0.2402
# inductive      0.05           GCN            0.8109    0.0325    0.2013
# inductive      0.05           GAT            0.8102    0.0329    0.2068
# inductive      0.05           SAGE           0.839     0.0278    0.1718
# inductive      0.05           GIN            0.7792    0.0381    0.2359
# inductive      0.1            GCN            0.8205    0.0313    0.1927
# inductive      0.1            GAT            0.808     0.0335    0.2058
# inductive      0.1            SAGE           0.8301    0.0291    0.1771
# inductive      0.1            GIN            0.7637    0.0404    0.2471
# inductive      0.2            GCN            0.8095    0.0329    0.2029
# inductive      0.2            GAT            0.8183    0.0312    0.2017
# inductive      0.2            SAGE           0.836     0.0281    0.1665
# inductive      0.2            GIN            0.7644    0.0406    0.2501
#
# Summary for CiteSeer:
# Setting        Mask Ratio     Architecture   Accuracy  FPR       FNR
# -----------------------------------------------------------------
# transductive   0.0            GCN            0.7042    0.0594    0.3289
# transductive   0.0            GAT            0.7207    0.0564    0.3164
# transductive   0.0            SAGE           0.7703    0.0465    0.263
# transductive   0.0            GIN            0.7102    0.0584    0.3222
# transductive   0.05           GCN            0.7207    0.0565    0.3138
# transductive   0.05           GAT            0.7132    0.0576    0.3229
# transductive   0.05           SAGE           0.7492    0.0505    0.2797
# transductive   0.05           GIN            0.7012    0.06      0.3313
# transductive   0.1            GCN            0.7072    0.0589    0.3277
# transductive   0.1            GAT            0.7267    0.0548    0.309
# transductive   0.1            SAGE           0.7688    0.0459    0.2665
# transductive   0.1            GIN            0.6982    0.0607    0.338
# transductive   0.2            GCN            0.7267    0.0549    0.3112
# transductive   0.2            GAT            0.7267    0.0549    0.3133
# transductive   0.2            SAGE           0.7673    0.0469    0.2604
# transductive   0.2            GIN            0.7177    0.0568    0.3134
# inductive      0.0            GCN            0.6677    0.0669    0.3599
# inductive      0.0            GAT            0.6941    0.0614    0.3333
# inductive      0.0            SAGE           0.7188    0.0566    0.3153
# inductive      0.0            GIN            0.6346    0.0735    0.3929
# inductive      0.05           GCN            0.6815    0.0643    0.347
# inductive      0.05           GAT            0.6935    0.0617    0.3386
# inductive      0.05           SAGE           0.7188    0.0565    0.3132
# inductive      0.05           GIN            0.652     0.07      0.3787
# inductive      0.1            GCN            0.6839    0.0637    0.3408
# inductive      0.1            GAT            0.6923    0.0619    0.3348
# inductive      0.1            SAGE           0.7218    0.0561    0.3175
# inductive      0.1            GIN            0.6466    0.0711    0.3821
# inductive      0.2            GCN            0.6803    0.0644    0.3447
# inductive      0.2            GAT            0.6797    0.0642    0.3429
# inductive      0.2            SAGE           0.7127    0.0576    0.3163
# inductive      0.2            GIN            0.6605    0.0682    0.3614
#
# Summary for PubMed:
# Setting        Mask Ratio     Architecture   Accuracy  FPR       FNR
# -----------------------------------------------------------------
# transductive   0.0            GCN            0.8324    0.0868    0.1742
# transductive   0.0            GAT            0.8496    0.0771    0.1535
# transductive   0.0            SAGE           0.8867    0.0588    0.1162
# transductive   0.0            GIN            0.839     0.0835    0.1662
# transductive   0.05           GCN            0.8372    0.0841    0.1689
# transductive   0.05           GAT            0.8451    0.08      0.1581
# transductive   0.05           SAGE           0.8945    0.0547    0.1071
# transductive   0.05           GIN            0.8479    0.0786    0.1586
# transductive   0.1            GCN            0.8382    0.0835    0.1671
# transductive   0.1            GAT            0.8367    0.0839    0.1678
# transductive   0.1            SAGE           0.8821    0.061     0.1191
# transductive   0.1            GIN            0.8296    0.0885    0.177
# transductive   0.2            GCN            0.8453    0.0804    0.1604
# transductive   0.2            GAT            0.84      0.0826    0.1674
# transductive   0.2            SAGE           0.873     0.0664    0.1302
# transductive   0.2            GIN            0.818     0.0944    0.1867
# inductive      0.0            GCN            0.8366    0.0845    0.1697
# inductive      0.0            GAT            0.8341    0.0855    0.17
# inductive      0.0            SAGE           0.8851    0.0599    0.1184
# inductive      0.0            GIN            0.829     0.0887    0.1792
# inductive      0.05           GCN            0.8323    0.0866    0.1755
# inductive      0.05           GAT            0.8349    0.0859    0.175
# inductive      0.05           SAGE           0.8812    0.0617    0.1221
# inductive      0.05           GIN            0.8275    0.0889    0.1784
# inductive      0.1            GCN            0.8277    0.0891    0.1788
# inductive      0.1            GAT            0.8341    0.085     0.1692
# inductive      0.1            SAGE           0.8727    0.0661    0.1318
# inductive      0.1            GIN            0.8221    0.0919    0.1885
# inductive      0.2            GCN            0.8387    0.0833    0.1669
# inductive      0.2            GAT            0.8301    0.088     0.1774
# inductive      0.2            SAGE           0.8727    0.0658    0.1295
# inductive      0.2            GIN            0.8221    0.0922    0.1859
#
# Summary for Amazon:
# Setting        Mask Ratio     Architecture   Accuracy  FPR       FNR
# -----------------------------------------------------------------
# transductive   0.0            GCN            0.904     0.0125    0.1074
# transductive   0.0            GAT            0.8873    0.0146    0.1302
# transductive   0.0            SAGE           0.8935    0.0139    0.1178
# transductive   0.0            GIN            0.687     0.0428    0.4942
# transductive   0.05           GCN            0.9044    0.0122    0.1029
# transductive   0.05           GAT            0.8855    0.0149    0.1356
# transductive   0.05           SAGE           0.8953    0.0137    0.115
# transductive   0.05           GIN            0.6968    0.0405    0.3962
# transductive   0.1            GCN            0.9026    0.0128    0.1079
# transductive   0.1            GAT            0.8873    0.0146    0.1331
# transductive   0.1            SAGE           0.896     0.0133    0.117
# transductive   0.1            GIN            0.7688    0.032     0.325
# transductive   0.2            GCN            0.9095    0.0119    0.103
# transductive   0.2            GAT            0.8866    0.0146    0.1283
# transductive   0.2            SAGE           0.8939    0.0136    0.1138
# transductive   0.2            GIN            0.7663    0.0324    0.3273
# inductive      0.0            GCN            0.9036    0.0124    0.1055
# inductive      0.0            GAT            0.887     0.0143    0.1296
# inductive      0.0            SAGE           0.8994    0.0126    0.1034
# inductive      0.0            GIN            0.7238    0.0385    0.3776
# inductive      0.05           GCN            0.9066    0.012     0.1025
# inductive      0.05           GAT            0.8934    0.0137    0.1159
# inductive      0.05           SAGE           0.8965    0.0131    0.1126
# inductive      0.05           GIN            0.6684    0.0471    0.5448
# inductive      0.1            GCN            0.9082    0.0118    0.1013
# inductive      0.1            GAT            0.888     0.0143    0.1255
# inductive      0.1            SAGE           0.8998    0.0125    0.1054
# inductive      0.1            GIN            0.7718    0.0317    0.3202
# inductive      0.2            GCN            0.902     0.0127    0.1141
# inductive      0.2            GAT            0.8992    0.0128    0.1024
# inductive      0.2            SAGE           0.9011    0.0125    0.1024
# inductive      0.2            GIN            0.7468    0.0347    0.3786
